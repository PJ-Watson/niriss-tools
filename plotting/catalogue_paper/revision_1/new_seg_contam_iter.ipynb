# %% [markdown]
# ### Generating a contamination model
#
# This notebook covers generating a segmentation map, detection catalogue, and contamination model.

# %% [markdown]
# As before, we setup the directory structure and environment variables.

# %%
import os
from pathlib import Path

# This is currently a necessity; newer pipeline reductions do not work well with grizli
os.environ["CRDS_CONTEXT"] = "jwst_1173.pmap"

root_dir = Path(os.getenv("ROOT_DIR"))

# %%
import shutil, logging
from astropy.io import fits
import grizli
from grizli import utils, prep, jwst_utils, multifit
from grizli.pipeline import auto_script
import numpy as np

print("Grizli version: ", grizli.__version__)

# Quiet JWST log warnings
jwst_utils.QUIET_LEVEL = logging.WARNING
jwst_utils.set_quiet_logging(jwst_utils.QUIET_LEVEL)

root_name = "glass-a2744"

# Set up the grizli directory structure
grizli_home_dir = root_dir / "2024_08_16_A2744_v4" / "grizli_home_refine_contam"
(grizli_home_dir / "Prep").mkdir(exist_ok=True, parents=True)
(grizli_home_dir / "Extractions").mkdir(exist_ok=True, parents=True)

os.chdir(grizli_home_dir / "Prep")
# Out:
# Grizli version:  1.12.8

# %% [markdown]
# Let's start by generating a catalogue with the default parameters, and seeing how that looks.

# %%
# multiband_catalog_args = auto_script.get_yml_parameters()["multiband_catalog_args"]

# phot_cat = auto_script.multiband_catalog(field_root=root_name, **multiband_catalog_args)

# %% [markdown]
# We show a quick plot of the areas not included in the segmentation map.

# %%
# from astropy.table import Table, join
# from astropy.coordinates import SkyCoord, match_coordinates_sky
# import matplotlib.pyplot as plt
# import astropy.visualization as astrovis

# plot = True

# prev_seg_map = fits.getdata(f"{root_name}-ir_seg.fits").astype(int)

# detect_img = fits.getdata(f"{root_name}-ir_drc_sci.fits")

# if plot:

#     fig, axs = plt.subplots(1, 2, sharex=True, sharey=True)
#     plot_kwargs = {
#         "norm": astrovis.ImageNormalize(
#             detect_img,
#             interval=astrovis.ManualInterval(0, 5),
#             stretch=astrovis.LogStretch(),
#         ),
#         "origin": "lower",
#         "cmap": "plasma",
#     }
#     axs[0].imshow(
#         detect_img,
#         **plot_kwargs,
#     )
#     axs[1].imshow(
#         detect_img * (1 - (prev_seg_map > 0)),
#         **plot_kwargs,
#     )

# %% [markdown]
# A significant fraction of the light in the cluster is not included in the segmentation map. This missing light will not be accounted for in the contamination model, and will cause problems for any overlapping objects in the dispersed image.
#
# This can be solved by making two changes:
#
# * Lowering the detection threshold.
# * Not subtracting a background from the detection image.
#
# The latter is particularly important for cluster observations.
#
# Here, we use `photutils` to generate a new segmentation map. The primary purpose here is to include as much of the light as possible; the exact source deblending is a matter of preference.

# %%
# from astropy.convolution import convolve, Gaussian2DKernel
# from photutils.segmentation import SegmentationImage, SourceCatalog, SourceFinder

# detect_img = fits.getdata(f"{root_name}-ir_drc_sci.fits")
# detect_wht = fits.getdata(f"{root_name}-ir_drc_wht.fits")

# err = np.sqrt(1 / detect_wht)

# pixel_stddev = 3

# # Smooth the detection image
# conv_detect = convolve(detect_img, Gaussian2DKernel(pixel_stddev))

# # Mask any bad pixels
# mask = (~np.isfinite(detect_img)) | (~np.isfinite(err)) | (~np.isfinite(detect_img))

# # The minimum contrast ratio between detected peaks when deblending
# contrast = 1e-5
# # The number of levels to use when deblending
# nlevels = 32
# # The minimum number of connected pixels for a source to be detected
# npixels = 9
# # The number of CPU processes to use for deblending
# nproc = 16
# # The connectivity for each pixel: 8 includes diagonal connections
# connectivity = 8

# finder = SourceFinder(
#     npixels=npixels,
#     nlevels=nlevels,
#     contrast=contrast,
#     nproc=16,
#     connectivity=connectivity,
# )
# segment_map = finder(
#     conv_detect,
#     threshold=1.0 * err, # Use a low detection threshold
# )

# new_seg_hdul = fits.HDUList(
#     hdus=[
#         fits.PrimaryHDU(
#             data=segment_map.copy(),
#             header=fits.getheader(f"{root_name}-ir_drc_sci.fits"),
#         ),
#     ]
# )
# new_seg_hdul.writeto(
#     f"photutils_seg_map_{nlevels}_{contrast:.0E}_{connectivity}.fits", overwrite=True
# )

# %% [markdown]
# <div class="alert alert-info">
#
# **Note:**
#
# At this point, further source deblending is a matter of personal preference, and will heavily depend on the individual science case. For the GLASS A2744 field, I combined the `photutils` segmentation map with a previous `sep`-derived map manually, as `sep` (or `sep-pjw`) produced more irregular shapes, better matched to the shape of the PSF from foreground stars. For most cases, the `photutils` map is likely to be sufficient.
#
# </div>

# %% [markdown]
# Now we regenerate both the detection catalogue, and multiband photometric catalogue, following the `grizli` format for both.

# %%
# from glass_niriss.pipeline import regen_catalogue

# # Or whatever name you came up with after the previous step
# # prev_seg_name = f"forced_extract_seg.fits"
# prev_seg_name = "glass-a2744-ir_seg_mod_3_ordered2.fits"

# segment_map = fits.getdata(prev_seg_name)

# use_regen_seg = np.asarray(segment_map).astype(np.int32)
# new_cat = regen_catalogue(
#     use_regen_seg,
#     root=f"{root_name}-ir",
# )
# Out:
# make_SEP_catalog: sep version = 1.4.1
# # (2025-05-09 10:30:58.471)
# make_SEP_catalog: glass-a2744-ir_drc_sci.fits weight=glass-a2744-ir_drc_wht.fits (MAP_WEIGHT)
# make_SEP_catalog: Image AB zeropoint =  28.900
# # (2025-05-09 10:30:58.778)
# SEP: Get background {'bw': 128.00000000000028, 'bh': 128.00000000000028, 'fw': 3, 'fh': 3}
#    SEP: Extract...
# Using old segmentation map
# Convolved
# kron_radius:   0%|          | 0/3494 [00:00<?, ?it/s]
# kron_photometry:   0%|          | 0/3494 [00:00<?, ?it/s]
# label     xcentroid      ...        kron_flux             kron_fluxerr
#                          ...
# ----- ------------------ ... ----------------------- ----------------------
#     1  4798.201677250802 ...   1.897288797380579e+39                    inf
#     2  4821.757448995615 ... -4.8242188651040344e+35  1.711752477275805e+18
#     3  4645.540421831696 ... -3.4175951922362716e+35   7.24336880458577e+18
#     4  4799.641575880165 ...  -6.336451252138208e+38  2.149363091120728e+19
#     5   4462.51786687284 ...  -3.349080751605681e+37  7.740129364236894e+18
#     6  4658.104765345749 ... -1.0306617666484643e+38                    inf
#     7  4680.222970924751 ...   4.100236308699418e+38 1.2605690513428056e+19
#   [1.32324062e+39 2.10707280e+40 3.43416877e+41 5.64417801e+42]
#   [1.66935947e+40 2.65979933e+41 4.34268049e+42 7.14914449e+43]
#   [2.13218740e+41 3.39624539e+42 5.55166561e+43 9.15059561e+44]]]
# [[2.67830070e+39 1.26420285e+41 7.52944412e+42 4.92719111e+44]
#  [8.03193680e+40 3.64909378e+42 2.16745367e+44 1.42738835e+46]
#  [3.20234128e+42 1.45715681e+44 8.70265356e+45 5.75743040e+47]
#  [1.48146636e+44 6.87463964e+45 4.13128813e+47 2.73477491e+49]]
# label     xcentroid         ycentroid     sky_centroid bbox_xmin bbox_xmax bbox_ymin bbox_ymax  area   semimajor_sigma   semiminor_sigma       orientation        eccentricity          min_value              max_value       local_background      segment_flux     segment_fluxerr       kron_flux       kron_fluxerr
#                                                                                                 pix2         pix               pix                 deg
# ----- ----------------- ----------------- ------------ --------- --------- --------- --------- ------ ----------------- ------------------ ------------------- ------------------ ---------------------- --------------------- ---------------- --------------------- --------------- --------------------- ------------
#     1 4798.201677250802 278.9889284201667         None      4751      4838       249       326 2214.0 24.34698747195346 16.936004294753786 -10.147925920008447 0.7184197499180515 -2.350305545285648e+38 3.310880464114591e+38              0.0 2.502281197924646e+39             inf 1.897288797380579e+39          inf
# 4751
# 4838
# area 2214.0 pix2
# background None
# background_centroid nan
# background_ma None
# background_mean nan
# background_sum nan
# bbox BoundingBox(ixmin=4751, ixmax=4839, iymin=249, iymax=327)
# bbox_xmax 4838
# bbox_xmin 4751
# bbox_ymax 326
# bbox_ymin 249
# centroid [4798.20167725  278.98892842]
# centroid_quad:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 10
#       7 segment_map = fits.getdata(prev_seg_name)
#       9 use_regen_seg = np.asarray(segment_map).astype(np.int32)
# ---> 10 new_cat = regen_catalogue(
#      11     use_regen_seg,
#      12     root=f"{root_name}-ir",
#      13 )
#
# File /media/sharedData/python/py3.12_GLASS_pipeline/code/GLASS-NIRISS/src/glass_niriss/pipeline/misc.py:697, in regen_catalogue(new_seg_map, root, sci, wht, threshold, get_background, bkg_only, bkg_params, verbose, phot_apertures, aper_segmask, prefer_var_image, rescale_weight, err_scale, use_bkg_err, column_case, save_to_fits, include_wcs_extension, source_xy, compute_auto_quantities, autoparams, flux_radii, subpix, mask_kron, max_total_corr, detection_params, bkg_mask, pixel_scale, log, gain, extract_pixstack, sub_object_limit, exposure_footprints, suffix, full_mask, **kwargs)
#     694 print(source_cat.bbox_xmax[0])
#     696 for p in source_cat.properties:
# --> 697     print(p, getattr(source_cat[0], p))
#     699 rename_cols = {
#     700     "label": "number",
#     701     "area": "npix",
#    (...)
#     720     "maxval_yindex": "ypeak",
#     721 }
#     722 remove_cols = [
#     723     "skycentroid",
#     724 ]
#
# File /media/sharedData/python/py3.12_GLASS_pipeline/lib/python3.12/site-packages/astropy/utils/decorators.py:850, in lazyproperty.__get__(self, obj, owner)
#     848         val = obj_dict.get(self._key, _NotFound)
#     849         if val is _NotFound:
# --> 850             val = self.fget(obj)
#     851             obj_dict[self._key] = val
#     852 return val
#
# File /media/sharedData/python/py3.12_GLASS_pipeline/lib/python3.12/site-packages/photutils/segmentation/catalog.py:96, in use_detcat.<locals>._use_detcat(self, *args, **kwargs)
#      93 @functools.wraps(method)
#      94 def _use_detcat(self, *args, **kwargs):
#      95     if self._detection_cat is None:
# ---> 96         return method(self, *args, **kwargs)
#      98     return getattr(self._detection_cat, method.__name__)
#
# File /media/sharedData/python/py3.12_GLASS_pipeline/lib/python3.12/site-packages/photutils/segmentation/catalog.py:68, in as_scalar.<locals>._as_scalar(*args, **kwargs)
#      66 @functools.wraps(method)
#      67 def _as_scalar(*args, **kwargs):
# ---> 68     result = method(*args, **kwargs)
#      69     try:
#      70         return (result[0] if args[0].isscalar and len(result) == 1
#      71                 else result)
#
# File /media/sharedData/python/py3.12_GLASS_pipeline/lib/python3.12/site-packages/photutils/segmentation/catalog.py:1611, in SourceCatalog.centroid_quad(self)
#    1588 """
#    1589 The ``(x, y)`` centroid coordinate, calculated by fitting a 2D
#    1590 quadratic polynomial to the unmasked pixels in the source
#    (...)
#    1608 of the maximum pixel will be returned.
#    1609 """
#    1610 origin = np.transpose((self.bbox_xmin, self.bbox_ymin))
# -> 1611 return self.cutout_centroid_quad + origin
#
# File /media/sharedData/python/py3.12_GLASS_pipeline/lib/python3.12/site-packages/astropy/utils/decorators.py:850, in lazyproperty.__get__(self, obj, owner)
#     848         val = obj_dict.get(self._key, _NotFound)
#     849         if val is _NotFound:
# --> 850             val = self.fget(obj)
#     851             obj_dict[self._key] = val
#     852 return val
#
# File /media/sharedData/python/py3.12_GLASS_pipeline/lib/python3.12/site-packages/photutils/segmentation/catalog.py:96, in use_detcat.<locals>._use_detcat(self, *args, **kwargs)
#      93 @functools.wraps(method)
#      94 def _use_detcat(self, *args, **kwargs):
#      95     if self._detection_cat is None:
# ---> 96         return method(self, *args, **kwargs)
#      98     return getattr(self._detection_cat, method.__name__)
#
# File /media/sharedData/python/py3.12_GLASS_pipeline/lib/python3.12/site-packages/photutils/segmentation/catalog.py:68, in as_scalar.<locals>._as_scalar(*args, **kwargs)
#      66 @functools.wraps(method)
#      67 def _as_scalar(*args, **kwargs):
# ---> 68     result = method(*args, **kwargs)
#      69     try:
#      70         return (result[0] if args[0].isscalar and len(result) == 1
#      71                 else result)
#
# File /media/sharedData/python/py3.12_GLASS_pipeline/lib/python3.12/site-packages/photutils/segmentation/catalog.py:1580, in SourceCatalog.cutout_centroid_quad(self)
#    1577 nan_mask = (np.isnan(centroid_quad[:, 0])
#    1578             | np.isnan(centroid_quad[:, 1]))
#    1579 if np.any(nan_mask):
# -> 1580     centroid_quad[nan_mask] = self.cutout_centroid[nan_mask]
#    1582 return centroid_quad
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 2 but corresponding boolean dimension is 1

# %%
prev_cat_name = f"{root_name}-ir.cat.fits"

multiband_catalog_args = auto_script.get_yml_parameters()["multiband_catalog_args"]
multiband_catalog_args["run_detection"] = False
multiband_catalog_args["filters"] = ["f115wn-clear","f150wn-clear","f200wn-clear"]

if not (Path.cwd() / f"{root_name}_phot.fits").is_file():
    phot_cat = auto_script.multiband_catalog(
        field_root=root_name,
        master_catalog=prev_cat_name,
        **multiband_catalog_args,
    )

# %% [markdown]
# This was an attempt to use the NGDEEP GRISMCONF files. Results may vary; whilst the wavelength calibration for the first order spectra improved, the overall contamination model was a noticeable regression over the `*221215.conf` files used by default.

# %%
# # print (dir(grizli))
# # print (grizli.GRIZLI_PATH)
# # print (dir(grizli.grismconf))

# import requests, shutil
# from astropy.table import Table
# import numpy as np
# from scipy.interpolate import CubicSpline
# from itertools import product

# conf_dir = Path(grizli.GRIZLI_PATH) / "CONF"

# os.chdir(conf_dir)

# calib_name = "NGDEEP_NIRISS_CALIB-v5"
# orig_conf_dir = conf_dir / f"orig_{calib_name}"
# grizli_conf_dir = conf_dir / "wfss-grism-configuration"

# if not orig_conf_dir.is_dir():
#     response = requests.get(
#         f"https://zenodo.org/record/10955821/files/npirzkal/{calib_name}.zip?download=1"
#     )

#     with open(f"{calib_name}.zip", "wb") as f:
#         f.write(response.content)

#     shutil.unpack_archive(f"{calib_name}.zip", f"orig_{calib_name}")

#     for each_file in orig_conf_dir.glob("*/*"):  # grabs all files
#         print(each_file)
#         each_file.rename(orig_conf_dir / each_file.name)

# new_conf_dir = conf_dir / f"{calib_name}"

# if not new_conf_dir.is_dir():
#     new_conf_dir.mkdir()
#     for conf_file in orig_conf_dir.glob("*.conf"):
#         shutil.copy2(conf_file, new_conf_dir / conf_file.name)
#     filts = ["F115W", "F150W", "F200W"]
#     pupils = ["GR150C", "GR150R"]
#     orders = ["-1", "+0", "+1", "+2", "+3"]
#     # filt = "F200W"
#     # pupil = "GR150C"
#     # order = "-1"
#     for filt, pupil, order in product(filts, pupils, orders):
#         print(filt, pupil, order)
#         NP_path = [*orig_conf_dir.glob(f"*{pupil}*{filt}*{order}*")][0]
#         if order == "+1":
#             shutil.copy2(NP_path, new_conf_dir / NP_path.name)
#             continue
#         orig_NP_sens = Table.read(NP_path)
#         orig_GB_sens = Table.read(
#             [
#                 *grizli_conf_dir.glob(
#                     f"NIRISS.{pupil}.{filt}.{order}.*".replace("+", "")
#                 )
#             ][0]
#         )

        # # print (np.nansum(orig_NP_sens["sensitivity"]))
        # # print (np.nansum(orig_GB_sens["SENSITIVITY"]))
        # NP_diff = np.diff(orig_NP_sens["wavelength"])
        # # print (np.nanmedian(NP_diff), np.nanmax(NP_diff), np.nanmin(NP_diff))
        # GB_diff = np.diff(orig_GB_sens["WAVELENGTH"])
        # # print (np.argwhere(orig_GB_sens["SENSITIVITY"]>0))
        # # print (np.nanmedian(GB_diff), np.nanmax(GB_diff), np.nanmin(GB_diff))

        # # import matplotlib.pyplot as plt
        # # interp_GB = np.interp(orig_NP_sens["wavelength"], orig_GB_sens["WAVELENGTH"]/1e4, orig_GB_sens["SENSITIVITY"])
        # spline_GB = CubicSpline(
        #     orig_GB_sens["WAVELENGTH"] / 1e4, orig_GB_sens["SENSITIVITY"]
        # )
        # interp_GB = spline_GB(orig_NP_sens["wavelength"])
        # flux_scale = np.nansum(interp_GB) / np.nansum(orig_NP_sens["sensitivity"])
        # print(flux_scale)
        # # plt.plot(orig_NP_sens["wavelength"], interp_GB)
        # # plt.plot(orig_NP_sens["wavelength"], orig_NP_sens["sensitivity"])
        # # plt.plot(orig_NP_sens["wavelength"], orig_NP_sens["sensitivity"]*flux_scale)
        # # plt.show()
        # if order == "+0" and filt == "F150W":
        #     flux_scale *= 2
        # orig_NP_sens["sensitivity"] *= flux_scale
        # if order == "-1":
        #     orig_NP_sens["sensitivity"] = orig_NP_sens["sensitivity"][::-1]
        # orig_NP_sens.write(new_conf_dir / NP_path.name)

# for each_file in new_conf_dir.glob("*"):  # grabs all files
#     print(each_file)
#     shutil.copy2(each_file, conf_dir / each_file.name)
#     # each_file.rename(orig_conf_dir / each_file.name)

# # print ([*orig_conf_dir.glob(f"*{pupil}*{filt}*{order}*")])
# # print ([*grizli_conf_dir.glob(f"NIRISS.{pupil}.{filt}.{order}.*".replace("+",""))])
# # print (f"*{pupil}*{filt}*{order}*".strip("+"))


# # trg_path = src_path.parent # gets the parent of the folder
# # each_file.rename(trg_path.joinpath(each_file.name)) # moves to parent folder.

# %% [markdown]
# With a new segmentation map and detection catalogue in hand, we now generate the contamination models. There are several parameters that can be changed here; these are just the parameters used for the GLASS catalogue.
#
# <div class="alert alert-warning">
#
# **Warning:**
#
# Depending on the number of objects detected, generating the contamination models **will** require a significant amount of memory. It will also take 10-30 minutes to run. At least you only have to do it once.
#
# </div>

# %%
kwargs = auto_script.get_yml_parameters()
print (kwargs["grism_prep_args"])
# Out:
# {'gris_ref_filters': {'G102': ['F105W', 'F098M', 'F110W', 'F125W', 'F140W', 'F160W', 'F127M', 'F139M', 'F153M', 'F132N', 'F130N', 'F128N', 'F126N', 'F164N', 'F167N'], 'G141': ['ir', 'F140W', 'F160W', 'F125W', 'F105W', 'F110W', 'F098M', 'F127M', 'F139M', 'F153M', 'F132N', 'F130N', 'F128N', 'F126N', 'F164N', 'F167N'], 'G800L': ['opt', 'ir', 'F814W', 'F850LP', 'F606W', 'F435W', 'F775W']}, 'files': None, 'grisms_to_process': None, 'split_by_grism': True, 'prelim_mag_limit': 25, 'refine_niter': 3, 'refine_poly_order': 3, 'refine_fcontam': 0.5, 'refine_mag_limits': [18, 24], 'ds9': None, 'mask_mosaic_edges': False}

# %%
# The number of processes to use
cpu_count = 8

os.chdir(grizli_home_dir / "Prep")

rate_files = [str(s) for s in Path.cwd().glob("*_rate.fits")][:]
grism_files = [str(s) for s in Path.cwd().glob("*GrismFLT.fits")][:]

if len(grism_files)==0:

    grism_prep_args = kwargs["grism_prep_args"]

    # For now, turn off refining contamination model with polynomial fits
    grism_prep_args["refine_niter"] = 3
    grism_prep_args["refine_poly_order"] = 7

    # Flat-flambda spectra
    grism_prep_args["init_coeffs"] = [1.0]

    grism_prep_args["mask_mosaic_edges"] = False

    # Here we use all of the detected objects.
    # These can be adjusted based on how deep the spectra/visits are
    grism_prep_args["refine_mag_limits"] = [14.0, 50.0]
    grism_prep_args["prelim_mag_limit"] = 50.0

    # Which filter to use as direct image?  Will try in order of the list until a match is found.
    grism_prep_args["gris_ref_filters"] = {
        "GR150R": ["F115W", "F150W", "F200W"],
        "GR150C": ["F115W", "F150W", "F200W"],
    }

    grism_prep_args["files"] = rate_files
    grp = auto_script.grism_prep(
        field_root=root_name, pad=800, cpu_count=cpu_count, **grism_prep_args
    )
# Out:
# # (2025-05-09 10:40:25.081)
#
# auto_script.grism_prep(**{'field_root': 'glass-a2744', 'PREP_PATH': '../Prep', 'EXTRACT_PATH': '../Extractions', 'ds9': None, 'refine_niter': 3, 'gris_ref_filters': {'GR150R': ['F115W', 'F150W', 'F200W'], 'GR150C': ['F115W', 'F150W', 'F200W']}, 'force_ref': None, 'files': ['/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324001001_06101_00001_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324001001_06101_00002_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324001001_06101_00003_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324001001_08101_00001_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324001001_09101_00001_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324001001_09101_00002_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324001001_09101_00003_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324001001_09101_00004_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324001001_10101_00001_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324001001_10101_00002_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324001001_10101_00003_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324001001_10101_00004_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324007001_04101_00001_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324007001_04101_00002_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324007001_04101_00003_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324007001_04101_00004_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324007001_05101_00001_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324007001_05101_00002_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324007001_05101_00003_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324007001_05101_00004_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324007001_06101_00001_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324007001_06101_00002_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324007001_06101_00003_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324007001_08101_00001_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324007001_09101_00002_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324007001_09101_00003_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324007001_09101_00004_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324007001_10101_00001_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324007001_10101_00002_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324007001_10101_00003_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324007001_10101_00004_nis_rate.fits', '/media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Prep/jw01324007001_11101_0000 ...
#
# auto_script.grism_prep: group = f115wn-clear
# auto_script.grism_prep: N = 16
# auto_script.grism_prep: file 0 = jw01324007001_05101_00001_nis_rate.fits
# auto_script.grism_prep: file 1 = jw01324007001_05101_00002_nis_rate.fits
# auto_script.grism_prep: file 2 = jw01324007001_05101_00003_nis_rate.fits
# auto_script.grism_prep: file 3 = jw01324007001_05101_00004_nis_rate.fits
# auto_script.grism_prep: file 4 = jw01324001001_05101_00004_nis_rate.fits
# auto_script.grism_prep: file 5 = jw01324007001_03101_00004_nis_rate.fits
# auto_script.grism_prep: file 6 = jw01324007001_03101_00001_nis_rate.fits
# auto_script.grism_prep: file 7 = jw01324007001_03101_00002_nis_rate.fits
# auto_script.grism_prep: file 8 = jw01324007001_03101_00003_nis_rate.fits
# auto_script.grism_prep: file 9 = jw01324001001_03101_00001_nis_rate.fits
# auto_script.grism_prep: file 10 = jw01324001001_03101_00002_nis_rate.fits
# auto_script.grism_prep: file 11 = jw01324001001_03101_00003_nis_rate.fits
# auto_script.grism_prep: file 12 = jw01324001001_03101_00004_nis_rate.fits
# auto_script.grism_prep: file 13 = jw01324001001_05101_00001_nis_rate.fits
# auto_script.grism_prep: file 14 = jw01324001001_05101_00002_nis_rate.fits
# auto_script.grism_prep: file 15 = jw01324001001_05101_00003_nis_rate.fits
# auto_script.grism_prep: ref_file = glass-a2744-f115wn-clear_drc_sci.fits
# auto_script.grism_prep: seg_file = glass-a2744-ir_seg.fits
# auto_script.grism_prep: catalog  = glass-a2744-ir.cat.fits
# auto_script.grism_prep: polyx  = [0.6, 2.5]
# auto_script.grism_prep: pad  = 800
#
#
# Image cutout: x=slice(0, 6573, None), y=slice(0, 6429, None) [Out of range]
# jw01324007001
nis_rate.fits / blot segmentation glass-a2744-ir_seg.fits[0]
# Using default C-based coordinate transformation...
# Using default C-based coordinate transformation...
# Transform JWST WFSS: flip=True
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
# Files loaded - 45.28 sec.
# auto_script.grism_prep: group = f200wn-clear
# auto_script.grism_prep: N = 8
# auto_script.grism_prep: file 0 = jw01324001001_15101_00001_nis_rate.fits
# auto_script.grism_prep: file 1 = jw01324001001_15101_00002_nis_rate.fits
# auto_script.grism_prep: file 2 = jw01324001001_15101_00003_nis_rate.fits
# auto_script.grism_prep: file 3 = jw01324001001_15101_00004_nis_rate.fits
# auto_script.grism_prep: file 4 = jw01324001001_17101_00001_nis_rate.fits
# auto_script.grism_prep: file 5 = jw01324001001_17101_00002_nis_rate.fits
# auto_script.grism_prep: file 6 = jw01324001001_17101_00003_nis_rate.fits
# auto_script.grism_prep: file 7 = jw01324001001_17101_00004_nis_rate.fits
# auto_script.grism_prep: ref_file = glass-a2744-f200wn-clear_drc_sci.fits
# auto_script.grism_prep: seg_file = glass-a2744-ir_seg.fits
# auto_script.grism_prep: catalog  = glass-a2744-ir.cat.fits
# auto_script.grism_prep: polyx  = [0.6, 2.5]
# auto_script.grism_prep: pad  = 800
# Image cutout: x=slice(0, 6573, None), y=slice(0, 6429, None) [Out of range]
# jw01324001001_15101_00001_nis_rate.fits / blot reference glass-a2744-f200wn-clear_drc_sci.fits[0]
# Using default C-based coordinate transformation...
# Image cutout: x=slice(0, 6573, None), y=slice(0, 6429, None) [Out of range]
# jw01324001001_15101_00001_nis_rate.fits / Pad ref HDU with 4395 pixels
# jw01324001001_15101_00001_nis_rate.fits / blot segmentation glass-a2744-ir_seg.fits[0]
# Using default C-based coordinate transformation...
# Using default C-based coordinate transformation...
# Transform JWST WFSS: flip=True
# Image cutout: x=slice(0, 6573, None), y=slice(0, 6429, None) [Out of range]
# jw01324001001_15101_00002_nis_rate.fits / blot reference glass-a2744-f200wn-clear_drc_sci.fits[0]
# Using default C-based coordinate transformation...
# Image cutout: x=slice(0, 6573, None), y=slice(0, 6429, None) [Out of range]
# jw01324001001_15101_00002_nis_rate.fits / Pad ref HDU with 4399 pixels
# jw01324001001_15101_00002_nis_rate.fits / blot segmentation glass-a2744-ir_seg.fits[0]
# Using default C-based coordinate transformation...
# Using default C-based coordinate transformation...
# Transform JWST WFSS: flip=True
# Image cutout: x=slice(0, 6573, None), y=slice(0, 6429, None) [Out of range]
# jw01324001001_15101_00003_nis_rate.fits / blot reference glass-a2744-f200wn-clear_drc_sci.fits[0]
# Using default C-based coordinate transformation...
# Image cutout: x=slice(0, 6573, None), y=slice(0, 6429, None) [Out of range]
# jw01324001001_15101_00003_nis_rate.fits / Pad ref HDU with 4416 pixels
# jw01324001001_15101_00003_nis_rate.fits / blot segmentation glass-a2744-ir_seg.fits[0]
# Using default C-based coordinate transformation...
# Using default C-based coordinate transformation...
# Transform JWST WFSS: flip=True
# Image cutout: x=slice(0, 6573, None), y=slice(0, 6429, None) [Out of range]
# jw01324001001_15101_00004_nis_rate.fits / blot reference glass-a2744-f200wn-clear_drc_sci.fits[0]
# Using default C-based coordinate transformation...
# Image cutout: x=slice(0, 6573, None), y=slice(0, 6429, None) [Out of range]
# jw01324001001_15101_00004_nis_rate.fits / Pad ref HDU with 4413 pixels
# jw01324001001_15101_00004_nis_rate.fits / blot segmentation glass-a2744-ir_seg.fits[0]
# Using default C-based coordinate transformation...
# Using default C-based coordinate transformation...
# Transform JWST WFSS: flip=True
# Image cutout: x=slice(0, 6573, None), y=slice(0, 6429, None) [Out of range]
# jw01324001001_17101_00001_nis_rate.fits / blot reference glass-a2744-f200wn-clear_drc_sci.fits[0]
# Using default C-based coordinate transformation...
# Image cutout: x=slice(0, 6573, None), y=slice(0, 6429, None) [Out of range]
# jw01324001001_17101_00001_nis_rate.fits / Pad ref HDU with 4304 pixels
# jw01324001001_17101_00001_nis_rate.fits / blot segmentation glass-a2744-ir_seg.fits[0]
# Using default C-based coordinate transformation...
# Using default C-based coordinate transformation...
# Transform JWST WFSS: flip=True
# Image cutout: x=slice(0, 6573, None), y=slice(0, 6429, None) [Out of range]
# jw01324001001_17101_00002_nis_rate.fits / blot reference glass-a2744-f200wn-clear_drc_sci.fits[0]
# Using default C-based coordinate transformation...
# Image cutout: x=slice(0, 6573, None), y=slice(0, 6429, None) [Out of range]
# jw01324001001_17101_00002_nis_rate.fits / Pad ref HDU with 4324 pixels
# jw01324001001_17101_00002_nis_rate.fits / blot segmentation glass-a2744-ir_seg.fits[0]
# Using default C-based coordinate transformation...
# Using default C-based coordinate transformation...
# Transform JWST WFSS: flip=True
# Image cutout: x=slice(0, 6573, None), y=slice(0, 6429, None) [Out of range]
# jw01324001001_17101_00003_nis_rate.fits / blot reference glass-a2744-f200wn-clear_drc_sci.fits[0]
# Using default C-based coordinate transformation...
# Image cutout: x=slice(0, 6573, None), y=slice(0, 6429, None) [Out of range]
# jw01324001001_17101_00003_nis_rate.fits / Pad ref HDU with 4319 pixels
# jw01324001001_17101_00003_nis_rate.fits / blot segmentation glass-a2744-ir_seg.fits[0]
# Using default C-based coordinate transformation...
# Using default C-based coordinate transformation...
# Transform JWST WFSS: flip=True
# Image cutout: x=slice(0, 6573, None), y=slice(0, 6429, None) [Out of range]
# jw01324001001_17101_00004_nis_rate.fits / blot reference glass-a2744-f200wn-clear_drc_sci.fits[0]
# Using default C-based coordinate transformation...
# Image cutout: x=slice(0, 6573, None), y=slice(0, 6429, None) [Out of range]
# jw01324001001_17101_00004_nis_rate.fits / Pad ref HDU with 4302 pixels
# jw01324001001_17101_00004_nis_rate.fits / blot segmentation glass-a2744-ir_seg.fits[0]
# Using default C-based coordinate transformation...
# Using default C-based coordinate transformation...
# Transform JWST WFSS: flip=True
# Files loaded - 23.20 sec.
# jw01324007001_05101_00002_nis_rate.fits: _compute_model Done
# jw01324007001_05101_00004_nis_rate.fits: _compute_model Done
# jw01324001001_05101_00004_nis_rate.fits: _compute_model Done
# jw01324007001_05101_00003_nis_rate.fits: _compute_model Done
# jw01324007001_05101_00001_nis_rate.fits: _compute_model Done
# jw01324007001_03101_00002_nis_rate.fits: _compute_model Done
# jw01324007001_03101_00001_nis_rate.fits: _compute_model Done
# jw01324001001_03101_00002_nis_rate.fits: _compute_model Done
# jw01324001001_05101_00002_nis_rate.fits: _compute_model Done
# jw01324001001_03101_00001_nis_rate.fits: _compute_model Done
# jw01324001001_03101_00003_nis_rate.fits: _compute_model Done
#  1932 mag= 32.81 -6.11e-16  3.50e-15 -7.75e-15  7.71e-15 -1.92e-15 -2.61e-15  2.20e-15 -5.12e-16 xx
#  1245 mag= 33.14 -1.07e-16  5.34e-16 -8.99e-16  2.29e-16  1.12e-15 -1.52e-15  7.97e-16 -1.56e-16 xx
#  2153 mag= 33.37 -1.94e-16  1.25e-15 -3.45e-15  5.24e-15 -4.75e-15  2.58e-15 -7.76e-16  1.00e-16 xx
#  1808 mag= 33.46 -2.95e-16  1.81e-15 -4.55e-15  5.89e-15 -4.01e-15  1.17e-15  4.88e-17 -7.32e-17 xx
# Save jw01324001001_15101_00001_nis.01.GrismFLT.fits
# Save jw01324001001_15101_00002_nis.01.GrismFLT.fits
# Save jw01324001001_15101_00003_nis.01.GrismFLT.fits
# Save jw01324001001_15101_00004_nis.01.GrismFLT.fits
# Save jw01324001001_17101_00001_nis.01.GrismFLT.fits
# Save jw01324001001_17101_00002_nis.01.GrismFLT.fits
# Save jw01324001001_17101_00003_nis.01.GrismFLT.fits
# Save jw01324001001_17101_00004_nis.01.GrismFLT.fits

# %% [markdown]
# Let's try extracting an object to see how it looks.

# %%
os.chdir(grizli_home_dir / "Extractions")
flt_files = [str(s) for s in Path.cwd().glob("*GrismFLT.fits")][:]

grp = multifit.GroupFLT(
    grism_files=flt_files,
    catalog=f"{root_name}-ir.cat.fits",
    cpu_count=-1,
    sci_extn=1,
    pad=800,
)
from grizli import fitting

pline = {
    "kernel": "square",
    "pixfrac": 1.0,
    "pixscale": 0.03,
    "size": 50,
    "wcs": None,
}
args = auto_script.generate_fit_params(
    pline=pline,
    field_root=root_name,
    min_sens=0.0,
    min_mask=0.0,
    # Set both of these to True to include photometry in fitting
    include_photometry=False,  
    use_phot_obj=False,
)

obj_id = 2663
obj_z = 2.6724

obj_id = 2938
obj_z = 1.891

beams = grp.get_beams(
    obj_id,
    size=25, 
    min_mask=0,
    min_sens=0,
    show_exception=True,
    beam_id="A",
)
mb = multifit.MultiBeam(
    beams, fcontam=0.2, min_sens=0.0, min_mask=0, group_name=root_name
)
# mb.fit_trace_shift()
mb.write_master_fits()

_ = fitting.run_all_parallel(
    obj_id,
    zr=[obj_z-0.01, obj_z + 0.01],
    dz=[0.001,0.0001],
    verbose=True,
    get_output_data=True,
    skip_complete=False,
    save_figures=True,
)
# Out:
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_03101_00001_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_05101_00003_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_05101_00004_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_09101_00001_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_09101_00002_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_09101_00003_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_09101_00004_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_11101_00001_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_11101_00002_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_11101_00003_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_11101_00004_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_15101_00001_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_15101_00002_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_03101_00002_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_15101_00003_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_15101_00004_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_17101_00001_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_17101_00002_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_17101_00003_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_17101_00004_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324007001_03101_00001_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324007001_03101_00002_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324007001_03101_00003_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324007001_03101_00004_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324007001_05101_00001_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324007001_05101_00002_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324007001_05101_00003_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324007001_05101_00004_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324007001_09101_00001_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324007001_09101_00002_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324007001_09101_00003_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324007001_09101_00004_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324007001_11101_00001_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324007001_11101_00002_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324007001_11101_00003_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324007001_11101_00004_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_03101_00003_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_03101_00004_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_05101_00001_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
# Load /media/sharedData/data/2024_08_16_A2744_v4/grizli_home_refine_contam/Extractions/jw01324001001_05101_00002_nis.01.GrismFLT.fits!
# Transform JWST WFSS: flip=True
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
#  ! Scale 0th order (B) by an additional x 1.5
# Files loaded - 20.87 sec.
# Saved arguments to fit_args.npy.
# glass-a2744_02938.beams.fits
# Run id=2938 with fit_args.npy
# load_master_fits: glass-a2744_02938.beams.fits
# 1 jw01324001001_03101_00001_nis_rate.fits GR150R
# 2 jw01324001001_05101_00003_nis_rate.fits GR150C
# 3 jw01324001001_05101_00004_nis_rate.fits GR150C
#  ! Scale 0th order (B) by an additional x 1.5
# 4 jw01324001001_09101_00001_nis_rate.fits GR150R
#  ! Scale 0th order (B) by an additional x 1.5
# 5 jw01324001001_09101_00002_nis_rate.fits GR150R
#  ! Scale 0th order (B) by an additional x 1.5
# 6 jw01324001001_09101_00003_nis_rate.fits GR150R
#  ! Scale 0th order (B) by an additional x 1.5
# 7 jw01324001001_09101_00004_nis_rate.fits GR150R
#  ! Scale 0th order (B) by an additional x 1.5
# 8 jw01324001001_11101_00001_nis_rate.fits GR150C
#  ! Scale 0th order (B) by an additional x 1.5
# 9 jw01324001001_11101_00002_nis_rate.fits GR150C
#  ! Scale 0th order (B) by an additional x 1.5
# 10 jw01324001001_11101_00003_nis_rate.fits GR150C
#  ! Scale 0th order (B) by an additional x 1.5
# 11 jw01324001001_11101_00004_nis_rate.fits GR150C
# 12 jw01324001001_15101_00001_nis_rate.fits GR150R
# 13 jw01324001001_15101_00002_nis_rate.fits GR150R
# 14 jw01324001001_03101_00002_nis_rate.fits GR150R
# 15 jw01324001001_15101_00003_nis_rate.fits GR150R
# 16 jw01324001001_15101_00004_nis_rate.fits GR150R
# 17 jw01324001001_17101_00001_nis_rate.fits GR150C
# 18 jw01324001001_17101_00002_nis_rate.fits GR150C
# 19 jw01324001001_17101_00003_nis_rate.fits GR150C
# 20 jw01324001001_17101_00004_nis_rate.fits GR150C
# 21 jw01324007001_03101_00001_nis_rate.fits GR150R
# 22 jw01324007001_03101_00002_nis_rate.fits GR150R
# 23 jw01324007001_03101_00003_nis_rate.fits GR150R
# 24 jw01324007001_03101_00004_nis_rate.fits GR150R
# 25 jw01324007001_05101_00001_nis_rate.fits GR150C
# 26 jw01324007001_05101_00002_nis_rate.fits GR150C
# 27 jw01324007001_05101_00003_nis_rate.fits GR150C
# 28 jw01324007001_05101_00004_nis_rate.fits GR150C
#  ! Scale 0th order (B) by an additional x 1.5
# 29 jw01324007001_09101_00001_nis_rate.fits GR150R
#  ! Scale 0th order (B) by an additional x 1.5
# 30 jw01324007001_09101_00002_nis_rate.fits GR150R
#  ! Scale 0th order (B) by an additional x 1.5
# 31 jw01324007001_09101_00003_nis_rate.fits GR150R
#  ! Scale 0th order (B) by an additional x 1.5
# 32 jw01324007001_09101_00004_nis_rate.fits GR150R
#  ! Scale 0th order (B) by an additional x 1.5
# 33 jw01324007001_11101_00001_nis_rate.fits GR150C
#  ! Scale 0th order (B) by an additional x 1.5
# 34 jw01324007001_11101_00002_nis_rate.fits GR150C
#  ! Scale 0th order (B) by an additional x 1.5
# 35 jw01324007001_11101_00003_nis_rate.fits GR150C
#  ! Scale 0th order (B) by an additional x 1.5
# 36 jw01324007001_11101_00004_nis_rate.fits GR150C
# 37 jw01324001001_03101_00003_nis_rate.fits GR150R
# 38 jw01324001001_03101_00004_nis_rate.fits GR150R
# 39 jw01324001001_05101_00001_nis_rate.fits GR150C
# 40 jw01324001001_05101_00002_nis_rate.fits GR150C
# User templates! N=17
#
#   1.8810   87619.1 (1.8810) 1/7
#   1.8839   87559.9 (1.8839) 2/7
#   1.8868   89041.3 (1.8839) 3/7
#   1.8897   91451.5 (1.8839) 4/7
#   1.8925   94842.6 (1.8839) 5/7
#   1.8954   99008.2 (1.8839) 6/7
#   1.8983  102871.8 (1.8839) 7/7
# First iteration: z_best=1.8839
#
# zgrid_zoom: 1.8839 [1.8807, 1.8871] N=23
# - 1.8807   87709.7 (1.8807) 1/23
# - 1.8810   87619.6 (1.8810) 2/23
# - 1.8813   87543.1 (1.8813) 3/23
# - 1.8816   87480.8 (1.8816) 4/23
# - 1.8819   87433.4 (1.8819) 5/23
# - 1.8822   87401.4 (1.8822) 6/23
# - 1.8824   87385.3 (1.8824) 7/23
# - 1.8827   87385.7 (1.8824) 8/23
# - 1.8830   87403.1 (1.8824) 9/23
# - 1.8833   87437.8 (1.8824) 10/23
# - 1.8836   87490.0 (1.8824) 11/23
# - 1.8839   87559.4 (1.8824) 12/23
# - 1.8842   87645.5 (1.8824) 13/23
# - 1.8845   87747.5 (1.8824) 14/23
# - 1.8847   87864.7 (1.8824) 15/23
# - 1.8850   87996.6 (1.8824) 16/23
# - 1.8853   88142.3 (1.8824) 17/23
# - 1.8856   88300.7 (1.8824) 18/23
# - 1.8859   88470.5 (1.8824) 19/23
# - 1.8862   88651.0 (1.8824) 20/23
# - 1.8865   88841.3 (1.8824) 21/23
# - 1.8868   89040.1 (1.8824) 22/23
# - 1.8871   89246.7 (1.8824) 23/23
# Drizzle line -> OII-7325 (-0.11 0.12)
# Drizzle line -> ArIII-7138 (0.14 0.13)
# Drizzle line -> SII  (0.85 0.13)
# Drizzle line -> Ha   (13.44 0.14)
# Drizzle line -> OI-6302 (0.00 0.14)
# Drizzle line -> HeI-5877 (-10.00 5.96)
# Drizzle line -> OIII (33.72 0.13)
# Drizzle line -> Hb   (3.61 0.11)
# Drizzle line -> OIII-4363 (-0.29 0.19)
# Drizzle line -> Hg   (1.75 0.19)
# Drizzle line -> Hd   (0.31 0.14)
# Drizzle line -> H7   (1.32 0.17)
# Drizzle line -> H8   (1.49 0.36)
# Drizzle line -> H9   (0.44 0.34)
# Drizzle line -> H10  (1.67 0.27)
# Drizzle line -> NeIII-3867 (1.27 0.45)
# Drizzle line -> OII  (6.30 0.26)
# Drizzle line -> NeVI-3426 (-10.00 901.51)
# Drizzle line -> NeV-3346 (-0.00 1181845.14)
# glass-a2744_02938.full.fits
