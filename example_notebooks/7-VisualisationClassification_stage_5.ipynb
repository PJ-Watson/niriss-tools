# %%
from pathlib import Path
import yaml
import os

root_dir = Path("/media") / "sharedData" / "data"
root_name = "glass-a2744"

catalogue_dir = root_dir / "2024_08_16_A2744_v4" / "glass_niriss" / "match_catalogues"

grizli_home_dir = root_dir / "2024_08_16_A2744_v4" / "grizli_home"
grizli_extraction_dir = grizli_home_dir / "Extractions_v2"

# %%
from astropy.table import Table, join, Column, vstack
import numpy as np

v2_out_dir = grizli_home_dir / "classification-stage-2"/"catalogues" / "compiled"
cat_others = Table.read(v2_out_dir  / "internal_stage_3_2.fits")

stage_3_dir = grizli_home_dir / "Extractions_v3"
stage_3_cat = Table.read(stage_3_dir / "classification" / "stage_3_PJW_class.fits")

force_dir = grizli_home_dir / "ForcedExtractions"
detect_cat = Table.read(force_dir / f"{root_name}-ir.cat.fits")

stage_4_dir = grizli_home_dir / "Extractions_v4"
(stage_4_dir / "catalogues").mkdir(exist_ok=True, parents=True)

stage_5_cat = Table.read( stage_4_dir / "catalogues" / "stage_4_input.fits")
stage_5_class_cat = Table.read( stage_4_dir / "classification" / "stage_4_PJW_class.fits")
# cat_others
# stage_3_cat

# %%
for i, row in enumerate(stage_5_cat):
    class_idx = np.argwhere(row["ID"]==stage_5_class_cat["ID"].astype(int))
    if class_idx.size > 0:
        # print (class_idx, )
        class_data = stage_5_class_cat[class_idx]
        if class_data["UNRELIABLE_REDSHIFT"]:
            stage_5_cat[i]["Z_FLAG"] = 2
        elif class_data["TENTATIVE_REDSHIFT"]:
            stage_5_cat[i]["Z_FLAG"] = 3

print(np.unique(np.array(stage_5_cat["Z_FLAG"]), return_counts=True))

stage_5_cat.write(stage_4_dir / "catalogues" / "stage_5_output_internal.fits", overwrite=True)
# Out:
# (array([0, 1, 2, 3, 4], dtype='>i8'), array([ 511,  907, 1744,  135,  357]))
# WARNING: VerifyWarning: Keyword name 'FILTER_TYPE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'THRESHOLD' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'BACK_PIXEL_SCALE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'ERR_SCALE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]

# %%
phot_cat = Table.read(force_dir / f"{root_name}_phot.fits")
phot_cat.rename_columns(phot_cat.colnames, [c.upper() for c in phot_cat.colnames])

stage_5_cat.remove_columns(["NUMBER","MAG_AUTO"])
stage_5_phot = join(stage_5_cat, phot_cat)
stage_5_phot.write(stage_4_dir / "catalogues" / "stage_5_output_internal_phot.fits", overwrite=True)
# Out:
# WARNING: MergeConflictWarning: Cannot merge meta key 'VERSION' types <class 'str'> and <class 'str'>, choosing VERSION='1.4.1.dev0+g261546c.d20250211' [astropy.utils.metadata.merge]
# WARNING: VerifyWarning: Keyword name 'FILTER_TYPE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'THRESHOLD' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'BACK_PIXEL_SCALE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'ERR_SCALE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_VERSION' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_ZP' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_PLAM' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_FNU' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_FLAM' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_uJy2dn' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_DRZ_FILE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_WHT_FILE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_GET_BACK' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_BACK_BW' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_BACK_BH' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_BACK_FW' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_BACK_FH' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_BACK_PIXEL_SCALE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_ERR_SCALE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_RESCALEW' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_APERMASK' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_KRONFACT' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_KRON0' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_KRON1' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_MINKRON' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_TOTCFILT' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_TOTCWAVE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_GAIN' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_aper_0' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_asec_0' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_aper_1' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_asec_1' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_aper_2' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_asec_2' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_aper_3' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_asec_3' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_aper_4' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_asec_4' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_aper_5' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_asec_5' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_aper_6' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F115WN_asec_6' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_VERSION' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_ZP' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_PLAM' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_FNU' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_FLAM' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_uJy2dn' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_DRZ_FILE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_WHT_FILE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_GET_BACK' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_BACK_BW' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_BACK_BH' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_BACK_FW' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_BACK_FH' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_BACK_PIXEL_SCALE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_ERR_SCALE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_RESCALEW' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_APERMASK' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_KRONFACT' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_KRON0' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_KRON1' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_MINKRON' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_TOTCFILT' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_TOTCWAVE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_GAIN' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_aper_0' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_asec_0' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_aper_1' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_asec_1' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_aper_2' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_asec_2' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_aper_3' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_asec_3' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_aper_4' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_asec_4' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_aper_5' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_asec_5' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_aper_6' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F150WN_asec_6' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_VERSION' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_ZP' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_PLAM' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_FNU' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_FLAM' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_uJy2dn' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_DRZ_FILE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_WHT_FILE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_GET_BACK' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_BACK_BW' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_BACK_BH' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_BACK_FW' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_BACK_FH' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_BACK_PIXEL_SCALE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_ERR_SCALE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_RESCALEW' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_APERMASK' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_KRONFACT' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_KRON0' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_KRON1' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_MINKRON' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_TOTCFILT' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_TOTCWAVE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_GAIN' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_aper_0' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_asec_0' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_aper_1' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_asec_1' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_aper_2' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_asec_2' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_aper_3' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_asec_3' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_aper_4' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_asec_4' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_aper_5' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_asec_5' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_aper_6' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'F200WN_asec_6' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]

# %%
from itertools import product
from numpy.lib.recfunctions import structured_to_unstructured

filters = ["F115W","F150W","F200W"]
pas = ["72.0","341.0"]

beam_names = [f"{a},{b}" for b, a in product(pas, filters)]
coverage_names = [f"{b}_COVERAGE" for b in beam_names]
quality_names = [f"{b}_QUALITY" for b in beam_names]
# new_names = [f"{b}_USE" for b in beam_names]

# %%
from numpy.typing import ArrayLike

def table_to_array(table: Table) -> ArrayLike:
    """
    Convert an astropy table to a numpy array.

    Parameters
    ----------
    table : Table
        Original astropy table.

    Returns
    -------
    ArrayLike
        Numpy array.
    """
    return np.lib.recfunctions.structured_to_unstructured(table.as_array())

# %%
unreliable = [
    2
]

# %%
column_names = [
    "ID",
    "RA","DEC","Z_NIRISS","Z_FLAG"
]
column_names.extend(quality_names)
column_names.extend(["Z_OUTSIDE", "Z_ON_EDGE", "Z_REFIT","DZ_1PZ"])

quality_mapping = {
    "Unusable":0,
    "Poor":1,
    "Good":2,
    "Excellent":3
}

# quality_names_others = [c for c in cat_others.colnames if any(q in c for q in quality_names)]
# print (quality_names_others)

# %%
# rows_to_use = (np.isin(stage_3_z_cat["NUMBER"],previous_ids) | (stage_3_z_cat["NUMBER"]>=3493)) & ~(stage_3_z_cat["NUMBER"].mask)

# %%
table_data = []

match_precision = 3

for row in detect_cat[:]:
    row_data = []
    stage_3_idx = np.argwhere(row["NUMBER"]==stage_3_cat["ID"].astype(int))
    other_idx = np.argwhere(row["NUMBER"]==cat_others["NUMBER"].astype(int))
    if stage_3_idx.size > 0:
        stage_3_row = stage_3_cat[stage_3_idx]
        if "rm" in stage_3_row["COMMENTS"].data[0,0].astype(str):
            print (f"Removing object {row["NUMBER"]}")
            continue
        # print (row["ID"])
        row_data.extend(*table_to_array(stage_3_row["ID","RA","DEC"]))
        z_d = [np.nan, 0]
        if stage_3_row["UNRELIABLE_REDSHIFT"]:
            z_d = [np.nan, 2]
        elif stage_3_row["TENTATIVE_REDSHIFT"]:
            z_d = [stage_3_row["ESTIMATED_REDSHIFT"][0][0],3]
        else:
            z_d = [stage_3_row["ESTIMATED_REDSHIFT"][0][0],4]
        # print (z_d)
        row_data.extend(z_d)
        # row_data.extend(*table_to_array(stage_3_row[coverage_names]))
        # print (row_data)
        # print (table_to_array(stage_3_row[duality_names]))
        row_data.extend([quality_mapping[q] for q in table_to_array(stage_3_row[quality_names])[0].astype(str)])
        # print (map(quality_mapping.get, row_data[quality_names].data))
        # print (stage_3_row["GRIZLI_REDSHIFT","ESTIMATED_REDSHIFT"])
        # try:
        if z_d[1] >=3:
            z_cat = Table.read(stage_3_dir / "full" / f"{root_name}_{int(stage_3_row["ID"][0][0]):0>5}.full.fits", "ZFIT_STACK")
            if (stage_3_row["ESTIMATED_REDSHIFT"]==np.nanmin(z_cat["zgrid"])) or (stage_3_row["ESTIMATED_REDSHIFT"]==np.nanmax(z_cat["zgrid"])):
                # print ("edge", stage_3_row["ID"])
                row_data.extend([False,True])
            elif (stage_3_row["ESTIMATED_REDSHIFT"]>np.nanmin(z_cat["zgrid"])) and (stage_3_row["ESTIMATED_REDSHIFT"]<np.nanmax(z_cat["zgrid"])):
                # print ("contained", stage_3_row["ID"][0])
                row_data.extend([False,False])
            elif (stage_3_row["ESTIMATED_REDSHIFT"]<np.nanmin(z_cat["zgrid"])) or (stage_3_row["ESTIMATED_REDSHIFT"]>np.nanmax(z_cat["zgrid"])):
                # print ("outside", stage_3_row["ID"][0])
                row_data.extend([True,False])

            if np.round(z_cat.meta["Z_MAP"],decimals=match_precision)==np.round(stage_3_row["ESTIMATED_REDSHIFT"][0][0], decimals=match_precision):
                row_data.extend([False,0.])
            else:
                # print (, stage_3_row["ESTIMATED_REDSHIFT"][0][0], "s3",stage_3_row["ID"][0][0])
                row_data.extend([True,(z_cat.meta["Z_MAP"]-stage_3_row["ESTIMATED_REDSHIFT"][0][0])/(1+z_cat.meta["Z_MAP"])])
        else:
            row_data.extend([False,False,False,0.])

        table_data.append(row_data)
    
    elif other_idx.size > 0:
        others_row = cat_others[other_idx]
        # print ()
        if others_row["NUMBER"].astype(int) in unreliable:
            others_row["Z_EST_V3"] = np.nan
            others_row["Z_FLAG_V3"] = 2

        row_data.extend(*table_to_array(others_row["NUMBER","RA","DEC","Z_EST_V3","Z_FLAG_V3"]))
        # row_data.extend(*table_to_array(stage_3_row[coverage_names]))
        # print (row_data)
        # print (table_to_array(stage_3_row[quality_names]))
        for q, c in zip(quality_names, coverage_names):
            # print (q,c)
            if not others_row[c] > 0.1:
                row_data.append(0)
                continue
            # q_names = [s for s in cat_others.colnames if q in s]
            # print (q_names)

            # print ([others_row[n] for n in q_names if not others_row[n].mask])
            q_data = np.nanmedian([int(others_row[n].data.data[0][0]) for n in [s for s in cat_others.colnames if q in s] if not others_row[n].mask])
            
            row_data.append(q_data)
            # print (others_row[q_names[0]].mask)
            # print (table_to_array(others_row[q_names]).astype(str).filled("")[0])
            # print ([quality_mapping[q] for q in table_to_array(others_row[q_names]).astype(str).filled("")[0]])
        # row_data.extend([quality_mapping[q] for q in table_to_array(stage_3_row[quality_names])[0].astype(str)])
        # print (map(quality_mapping.get, row_data[quality_names].data))

        if others_row["Z_FLAG_V3"] >=3:
            try:
                z_cat = Table.read(grizli_home_dir / "Extractions_v2" / "reextracted" / "full" / f"{root_name}_{int(others_row["ID"][0][0]):0>5}.full.fits", "ZFIT_STACK")
            except:
                # try:
                z_cat = Table.read(grizli_home_dir / "Extractions_v2" / "skipped" / "full" / f"{root_name}_{int(others_row["ID"][0][0]):0>5}.full.fits", "ZFIT_STACK")
            if (others_row["ESTIMATED_REDSHIFT"]==np.nanmin(z_cat["zgrid"])) or (others_row["ESTIMATED_REDSHIFT"]==np.nanmax(z_cat["zgrid"])):
                # print ("edge", stage_3_row["ID"])
                row_data.extend([False,True])
            elif (others_row["ESTIMATED_REDSHIFT"]>np.nanmin(z_cat["zgrid"])) and (others_row["ESTIMATED_REDSHIFT"]<np.nanmax(z_cat["zgrid"])):
                # print ("contained", stage_3_row["ID"][0])
                row_data.extend([False,False])
            elif (others_row["ESTIMATED_REDSHIFT"]<np.nanmin(z_cat["zgrid"])) or (others_row["ESTIMATED_REDSHIFT"]>np.nanmax(z_cat["zgrid"])):
                # print ("outside", stage_3_row["ID"][0])
                row_data.extend([True,False])
            
            if np.round(z_cat.meta["Z_MAP"],decimals=match_precision)==np.round(others_row["Z_EST_V3"][0][0], decimals=match_precision):
                row_data.extend([False,0.])
            else:
                row_data.extend([True, (z_cat.meta["Z_MAP"]-others_row["Z_EST_V3"][0][0])/(1+z_cat.meta["Z_MAP"])])
        else:
            row_data.extend([False,False,False, 0.])

        table_data.append(row_data)

# print (column_names)

# print (Table(names = column_names, data = tuple(zip(*table_data))))
print (len(column_names))
print (len(row_data))

stage_4_cat = Table(names = column_names, data = tuple(zip(*table_data)))
stage_4_cat
# Out:
# /media/sharedData/python/py3.12_GLASS_pipeline/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:1241: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /media/sharedData/python/py3.12_GLASS_pipeline/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:1241: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Removing object 171
# Removing object 206
# Removing object 225
# Removing object 228
# Removing object 260
# Removing object 277
# Removing object 281
# Removing object 291
# Removing object 295
# Removing object 328
# Removing object 334
# Removing object 340
# Removing object 348
# Removing object 374
# Removing object 384
# Removing object 390
# Removing object 409
# Removing object 427
# Removing object 455
# Removing object 541
# Removing object 571
# Removing object 667
# Removing object 678
# Removing object 680
# Removing object 685
# Removing object 757
# Removing object 771
# Removing object 789
# Removing object 795
# Removing object 834
# Removing object 850
# Removing object 934
# Removing object 978
# Removing object 979
# Removing object 1059
# Removing object 1090
# Removing object 1100
# Removing object 1122
# Removing object 1127
# Removing object 1135
# Removing object 1149
# Removing object 1153
# Removing object 1177
# Removing object 1203
# Removing object 1209
# Removing object 1214
# Removing object 1215
# Removing object 1217
# Removing object 1230
# Removing object 1251
# Removing object 1253
# Removing object 1258
# Removing object 1293
# Removing object 1308
# Removing object 1342
# Removing object 1345
# Removing object 1363
# Removing object 1391
# Removing object 1403
# Removing object 1409
# Removing object 1438
# Removing object 1446
# Removing object 1452
# Removing object 1467
# Removing object 1480
# Removing object 1571
# Removing object 1579
# Removing object 1588
# Removing object 1593
# Removing object 1599
# Removing object 1602
# Removing object 1645
# Removing object 1650
# Removing object 1668
# Removing object 1672
# Removing object 1680
# Removing object 1681
# Removing object 1708
# Removing object 1753
# Removing object 1780
# Removing object 1862
# Removing object 1880
# Removing object 1883
# Removing object 1924
# Removing object 1938
# Removing object 1950
# Removing object 1951
# Removing object 1974
# Removing object 1998
# Removing object 2028
# Removing object 2045
# Removing object 2108
# Removing object 2437
# Removing object 2666
# Removing object 3503
# Removing object 3505
# Removing object 3506
# Removing object 3507
# Removing object 3512
# Removing object 3515
# Removing object 3519
# Removing object 3529
# Removing object 3531
# Removing object 3552
# Removing object 3554
# Removing object 3556
# Removing object 3562
# Removing object 3563
# Removing object 3570
# Removing object 3571
# Removing object 3576
# Removing object 3580
# Removing object 3581
# Removing object 3585
# Removing object 3590
# Removing object 3597
# Removing object 3604
# Removing object 3605
# Removing object 3606
# Removing object 3610
# Removing object 3613
# Removing object 3616
# Removing object 3617
# Removing object 3618
# Removing object 3619
# Removing object 3621
# Removing object 3623
# Removing object 3626
# Removing object 3627
# Removing object 3633
# Removing object 3634
# Removing object 3637
# Removing object 3641
# Removing object 3645
# Removing object 3646
# Removing object 3647
# Removing object 3648
# Removing object 3656
# Removing object 3657
# Removing object 3662
# Removing object 3663
# Removing object 3664
# Removing object 3665
# Removing object 3666
# Removing object 3667
# Removing object 3668
# Removing object 3669
# Removing object 3675
# Removing object 3676
# Removing object 3682
# Removing object 3683
# Removing object 3692
# Removing object 3700
# Removing object 3706
# Removing object 3713
# Removing object 3715
# Removing object 3718
# Removing object 3721
# Removing object 3726
# Removing object 3727
# Removing object 3729
# Removing object 3730
# Removing object 3731
# Removing object 3732
# Removing object 3735
# Removing object 3736
# Removing object 3750
# Removing object 3751
# Removing object 3752
# Removing object 3754
# Removing object 3755
# Removing object 3757
# Removing object 3758
# Removing object 3759
# Removing object 3760
# Removing object 3763
# Removing object 3765
# Removing object 3766
# Removing object 3767
# Removing object 3768
# Removing object 3769
# Removing object 3786
# Removing object 3791
# Removing object 3810
# Removing object 3812
# Removing object 3814
# Removing object 3815
# Removing object 3816
# Removing object 3824
# Removing object 3825
# Removing object 3828
# Removing object 3830
# Removing object 3832
# Removing object 3833
# Removing object 3835
# Removing object 3841
# Removing object 3849
# Removing object 3850
# Removing object 3853
# Removing object 3854
# Removing object 3855
# Removing object 3856
# Removing object 3863
# Removing object 3866
# Removing object 3868
# Removing object 3869
# Removing object 3870
# Removing object 3874
# Removing object 3879
# Removing object 3880
# Removing object 3896
# 15
# 0
# <Table length=3654>
#    ID           RA                 DEC         ... Z_REFIT         DZ_1PZ
# bytes32      bytes32             bytes32       ...   bool         float64
# ------- ------------------ ------------------- ... ------- ---------------------
#     1.0  3.580726811401407  -30.41884945789135 ...   False                   0.0
#     2.0 3.5805950675838516  -30.41840626202294 ...   False                   0.0
#     3.0 3.5823409254568075 -30.418327649996915 ...   False                   0.0
#     4.0 3.5808351518242985 -30.418217634543268 ...   False                   0.0
#     5.0 3.5841284374988134 -30.417936732145677 ...   False                   0.0
#     6.0  3.582211382667949 -30.417880981654292 ...   False                   0.0
#     7.0  3.582027646479966 -30.417712181218253 ...   False                   0.0
#     8.0  3.582038666896761 -30.416994081787145 ...   False                   0.0
#     9.0 3.5826286452508738 -30.417417645847184 ...   False                   0.0
#     ...                ...                 ... ...     ...                   ...
#    3885  3.589180570206433 -30.393554307380025 ...   False                   0.0
#    3886  3.587417203822035 -30.393274774029894 ...   False                   0.0
#    3887  3.585502457703075 -30.397131486316074 ...   False                   0.0
#    3888 3.5858929913331883 -30.397876778451714 ...   False                   0.0
#    3890 3.5888912936923614 -30.394192078799254 ...   False                   0.0
#    3891 3.5896548918800266 -30.394312362697168 ...   False                   0.0
#    3892 3.5886194900737163 -30.392498093086235 ...   False                   0.0
#    3893  3.589819225299931 -30.394738869435557 ...   False                   0.0
#    3894  3.589316600889347  -30.39444469105094 ...   False                   0.0
#    3895 3.5876365919365396   -30.3963802664501 ...    True -0.013879753325114924

# %%
stage_4_cat["ID"] = [int(float(s)) for s in stage_4_cat["ID"]]
for c in ["RA","DEC","Z_NIRISS","DZ_1PZ"]:
    stage_4_cat[c] = [float(s) for s in stage_4_cat[c]]
for c in ["Z_FLAG"]+quality_names:
    stage_4_cat[c] = [int(s) if (np.isfinite(s)) else 0 for s in stage_4_cat[c]]
stage_4_cat
# Out:
# /tmp/ipykernel_935500/3341977897.py:3: UserWarning: Warning: converting a masked element to nan.
#   stage_4_cat[c] = [float(s) for s in stage_4_cat[c]]
# <Table length=3654>
#   ID          RA                 DEC         ... Z_REFIT         DZ_1PZ
# int64      float64             float64       ...   bool         float64
# ----- ------------------ ------------------- ... ------- ---------------------
#     1  3.580726811401407  -30.41884945789135 ...   False                   0.0
#     2 3.5805950675838516  -30.41840626202294 ...   False                   0.0
#     3 3.5823409254568075 -30.418327649996915 ...   False                   0.0
#     4 3.5808351518242985 -30.418217634543268 ...   False                   0.0
#     5 3.5841284374988134 -30.417936732145677 ...   False                   0.0
#     6  3.582211382667949 -30.417880981654292 ...   False                   0.0
#     7  3.582027646479966 -30.417712181218253 ...   False                   0.0
#     8  3.582038666896761 -30.416994081787145 ...   False                   0.0
#     9 3.5826286452508738 -30.417417645847184 ...   False                   0.0
#   ...                ...                 ... ...     ...                   ...
#  3885  3.589180570206433 -30.393554307380025 ...   False                   0.0
#  3886  3.587417203822035 -30.393274774029894 ...   False                   0.0
#  3887  3.585502457703075 -30.397131486316074 ...   False                   0.0
#  3888 3.5858929913331883 -30.397876778451714 ...   False                   0.0
#  3890 3.5888912936923614 -30.394192078799254 ...   False                   0.0
#  3891 3.5896548918800266 -30.394312362697168 ...   False                   0.0
#  3892 3.5886194900737163 -30.392498093086235 ...   False                   0.0
#  3893  3.589819225299931 -30.394738869435557 ...   False                   0.0
#  3894  3.589316600889347  -30.39444469105094 ...   False                   0.0
#  3895 3.5876365919365396   -30.3963802664501 ...    True -0.013879753325114924

# %%
# Benedetta's high-z galaxy
stage_4_cat["Z_FLAG"][stage_4_cat["ID"]==2992] = 4

# From Boyett+22
stage_4_cat["Z_FLAG"][stage_4_cat["ID"]==1043] = 3
stage_4_cat["Z_NIRISS"][stage_4_cat["ID"]==1043] = 1.342
stage_4_cat["Z_ON_EDGE"][stage_4_cat["ID"]==1043] = True

# From Boyett+22
stage_4_cat["Z_FLAG"][stage_4_cat["ID"]==2964] = 3
stage_4_cat["Z_NIRISS"][stage_4_cat["ID"]==2964] = 1.485
stage_4_cat["Z_ON_EDGE"][stage_4_cat["ID"]==2964] = True

# From Boyett+22
stage_4_cat["Z_FLAG"][stage_4_cat["ID"]==749] = 3
stage_4_cat["Z_NIRISS"][stage_4_cat["ID"]==749] = 1.043
stage_4_cat["Z_ON_EDGE"][stage_4_cat["ID"]==749] = True

stage_4_cat[stage_4_cat["ID"]==3518]
# stage_4_cat[stage_4_cat["ID"]==3518]
stage_4_cat[stage_4_cat["ID"]==749]

# 1043 1.342
# 2694 1.485
# 749  1.043
# Out:
# <Table length=1>
#   ID          RA               DEC        Z_NIRISS ... Z_ON_EDGE Z_REFIT  DZ_1PZ
# int64      float64           float64      float64  ...    bool     bool  float64
# ----- ----------------- ----------------- -------- ... --------- ------- -------
#   749 3.595889370351209 -30.4044265434742    1.043 ...      True   False     0.0

# %%
from astropy.coordinates import SkyCoord, match_coordinates_sky

stage_4_coords = SkyCoord(ra=stage_4_cat["RA"], dec=stage_4_cat["DEC"], unit="deg")

high_z_data = np.array(
    [
        ["YD4", 3.6038544, -30.3822365, 7.8758],
        ["YD7", 3.6033909, -30.3822289, 7.8772],
        ["ZD6", 3.6065702, -30.3808918, 7.8843],
        ["YD8", 3.5960841, -30.3858051, 7.8869],
        ["ZD2", 3.6045184, -30.3804321, 7.8800],
        ["ZD3", 3.6064637, -30.3809624, 7.8816],
        ["GLASSz8-2", 3.6013467, -30.3791904, 7.8831],
        ["GLASSz8-1", 3.60452, -30.38047, 8.04],
        ["JD1", 3.5950014, -30.4007411, 9.793],
    ]
)
high_z_prev = Table(names=["ID", "RA", "DEC", "Z"], data=high_z_data)
# # Roberts-Borsani+22
# high_z_prev.add_row([3.60451, -30.38046, 8.04])
# high_z_prev.add_row([3.60135, -30.37921, 7.90])


high_z_coords = SkyCoord(ra=high_z_prev["RA"], dec=high_z_prev["DEC"], unit="deg")
# high_z_prev["RA"] = [3.60451,3.60135]
# high_z_prev["DEC"] = [3.60451,3.60135]
#     data=[
#         [1,2,3],
#         [1,3,4]
#     ]
# )
# high_z_prev
idxs, sep, _ = match_coordinates_sky(high_z_coords, stage_4_coords)

for row, idx in zip(high_z_data,idxs):
    print (np.asarray(stage_4_cat["ID","Z_NIRISS"][idx]), row)
# Out:
# (2913, nan) ['YD4' '3.6038544' '-30.3822365' '7.8758']
# (2921, nan) ['YD7' '3.6033909' '-30.3822289' '7.8772']
# (3013, 8.196890547146845) ['ZD6' '3.6065702' '-30.3808918' '7.8843']
# (2514, 8.055710330435605) ['YD8' '3.5960841' '-30.3858051' '7.8869']
# (3062, 7.875000000000002) ['ZD2' '3.6045184' '-30.3804321' '7.88']
# (3009, 8.162609215993601) ['ZD3' '3.6064637' '-30.3809624' '7.8816']
# (3162, 7.878) ['GLASSz8-2' '3.6013467' '-30.3791904' '7.8831']
# (3062, 7.875000000000002) ['GLASSz8-1' '3.60452' '-30.38047' '8.04']
# (1121, nan) ['JD1' '3.5950014' '-30.4007411' '9.793']

# %%
from astropy.coordinates import SkyCoord, match_coordinates_sky

stage_4_coords = SkyCoord(ra=stage_4_cat["RA"], dec=stage_4_cat["DEC"], unit="deg")

high_z_data = np.array(
    [
        ["YD4", 3.6038544, -30.3822365, 7.8758],
        ["YD7", 3.6033909, -30.3822289, 7.8772],
        ["ZD6", 3.6065702, -30.3808918, 7.8843],
        ["YD8", 3.5960841, -30.3858051, 7.8869],
        ["ZD2", 3.6045184, -30.3804321, 7.8800],
        ["ZD3", 3.6064637, -30.3809624, 7.8816],
        ["GLASSz8-2", 3.6013467, -30.3791904, 7.8831],
        ["GLASSz8-1", 3.60452, -30.38047, 8.04],
        ["JD1", 3.5950014, -30.4007411, 9.793],
    ]
)
high_z_prev = Table(names=["ID", "RA", "DEC", "Z"], data=high_z_data)
# # Roberts-Borsani+22
# high_z_prev.add_row([3.60451, -30.38046, 8.04])
# high_z_prev.add_row([3.60135, -30.37921, 7.90])


high_z_coords = SkyCoord(ra=high_z_prev["RA"], dec=high_z_prev["DEC"], unit="deg")
# high_z_prev["RA"] = [3.60451,3.60135]
# high_z_prev["DEC"] = [3.60451,3.60135]
#     data=[
#         [1,2,3],
#         [1,3,4]
#     ]
# )
# high_z_prev
idxs, sep, _ = match_coordinates_sky(high_z_coords, stage_4_coords)

for row, idx in zip(high_z_data,idxs):
    print (np.asarray(stage_4_cat["ID","Z_NIRISS"][idx]), row)
# Out:
# (2913, nan) ['YD4' '3.6038544' '-30.3822365' '7.8758']
# (2921, nan) ['YD7' '3.6033909' '-30.3822289' '7.8772']
# (3013, 8.196890547146845) ['ZD6' '3.6065702' '-30.3808918' '7.8843']
# (2514, 8.055710330435605) ['YD8' '3.5960841' '-30.3858051' '7.8869']
# (3062, 7.875000000000002) ['ZD2' '3.6045184' '-30.3804321' '7.88']
# (3009, 8.162609215993601) ['ZD3' '3.6064637' '-30.3809624' '7.8816']
# (3162, 7.878) ['GLASSz8-2' '3.6013467' '-30.3791904' '7.8831']
# (3062, 7.875000000000002) ['GLASSz8-1' '3.60452' '-30.38047' '8.04']
# (1121, nan) ['JD1' '3.5950014' '-30.4007411' '9.793']

# %%
import astropy.units as u
# boyett+22
boyett_tab = Table.read(catalogue_dir / "Boyett+22.fits")

boyett_coords = SkyCoord(ra=boyett_tab["RAdeg"], dec=boyett_tab["DEdeg"], unit="deg")

idxs, sep, _ = match_coordinates_sky(boyett_coords, stage_4_coords)

for row, idx, s in zip(boyett_tab,idxs, sep):
    if s>0.5*u.arcsec:
        continue 
    # print (row["z"],stage_4_cat["Z_NIRISS"][idx])
    glass = stage_4_cat[idx]
    dz = (row["z"]-glass["Z_NIRISS"])/(1+row["z"])
    if np.abs(dz)>1e-3:
        if np.abs(dz)>0.02:
            print ("!!")
        print (f"Boyett: {row["ID"]: >5}, z={row["z"]:.3f}, GLASS: {glass["ID"]: >5}, z={glass["Z_NIRISS"]:.3f}")
    if not np.isfinite(dz):
        if np.abs(dz)>0.02:
            print ("!!")
        print (f"Boyett: {row["ID"]: >5}, z={row["z"]:.3f}, GLASS: {glass["ID"]: >5}, z={glass["Z_NIRISS"]:.3f}, sep={s.to(u.arcsec):.3f}")
        #, np.array(row["z"]), , s.to(u.arcsec), np.array(list(,"Z_NIRISS"][idx])))


# 749
# 3518
# 3166
# 3501
# 2599

# 1043 1.342
# 2964 1.485
# 749  1.043
# Out:
# Boyett:   328, z=1.038, GLASS:  3518, z=nan, sep=0.093 arcsec
# Boyett:  2081, z=1.039, GLASS:  2216, z=1.041
# Boyett:  2243, z=1.039, GLASS:  2373, z=1.042
# Boyett:  2201, z=1.051, GLASS:  2346, z=1.045
# Boyett:  2872, z=1.098, GLASS:  3166, z=nan, sep=0.076 arcsec
# Boyett:   189, z=1.041, GLASS:  3501, z=nan, sep=0.355 arcsec
# Boyett:   553, z=1.118, GLASS:   521, z=1.091
# Boyett:   442, z=1.099, GLASS:   452, z=1.097
# Boyett:   187, z=1.102, GLASS:   197, z=1.097
# !!
# Boyett:  1738, z=1.098, GLASS:  1776, z=1.243
# Boyett:   277, z=1.096, GLASS:   341, z=1.099
# Boyett:   699, z=1.104, GLASS:  3609, z=1.101
# Boyett:   515, z=1.108, GLASS:   523, z=1.103
# Boyett:  1710, z=1.166, GLASS:  1642, z=1.159
# Boyett:  2063, z=1.168, GLASS:  2166, z=1.163
# Boyett:  1972, z=1.159, GLASS:  2091, z=1.156
# Boyett:  1761, z=1.170, GLASS:  1823, z=1.167
# !!
# Boyett:  1532, z=1.125, GLASS:  1511, z=2.645
# Boyett:  2352, z=1.227, GLASS:  2599, z=nan, sep=0.091 arcsec
# Boyett:   138, z=1.275, GLASS:   142, z=1.268
# Boyett:   205, z=1.290, GLASS:   213, z=1.283
# Boyett:   215, z=1.342, GLASS:   229, z=1.335
# Boyett:  2325, z=1.346, GLASS:  2534, z=1.335
# Boyett:  1087, z=1.350, GLASS:  1092, z=1.343
# Boyett:  1865, z=1.345, GLASS:  3881, z=1.340
# Boyett:  2483, z=1.349, GLASS:  2793, z=1.343
# Boyett:  2652, z=1.328, GLASS:  2972, z=1.350
# Boyett:  2745, z=1.348, GLASS:  3064, z=1.353
# Boyett:  2137, z=1.360, GLASS:  2282, z=1.353
# Boyett:  2111, z=1.362, GLASS:  2250, z=1.353
# Boyett:  2110, z=1.364, GLASS:  2258, z=1.357
# Boyett:  2247, z=1.369, GLASS:  2352, z=1.364
# Boyett:  1685, z=1.371, GLASS:  1694, z=1.365
# Boyett:  2022, z=1.367, GLASS:  2074, z=1.362
# Boyett:  1911, z=2.213, GLASS:  3842, z=2.205
# Boyett:  2479, z=1.507, GLASS:  2762, z=1.498
# Boyett:  2657, z=1.502, GLASS:  2990, z=1.499
# Boyett:  2738, z=1.640, GLASS:  3085, z=nan, sep=0.132 arcsec
# Boyett:   827, z=1.697, GLASS:   699, z=nan, sep=0.376 arcsec
# Boyett:   286, z=1.735, GLASS:   318, z=nan, sep=0.283 arcsec
# Boyett:  2205, z=1.864, GLASS:  2355, z=1.858
# Boyett:  1208, z=1.872, GLASS:  1221, z=1.858
# Boyett:  2616, z=1.885, GLASS:  2938, z=1.891
# Boyett:   320, z=2.021, GLASS:   380, z=2.007
# Boyett:  1002, z=2.012, GLASS:   998, z=2.017
# Boyett:   451, z=2.018, GLASS:   458, z=2.012
# Boyett:  2289, z=2.194, GLASS:  2492, z=2.187
# Boyett:  1886, z=2.178, GLASS:  1991, z=2.185
# Boyett:  2139, z=2.329, GLASS:  2255, z=2.320
# Boyett:   546, z=2.666, GLASS:  3591, z=2.650
# Boyett:  2123, z=2.838, GLASS:  2273, z=2.848
# Boyett:  2314, z=2.927, GLASS:  2549, z=2.934
# Boyett:  1491, z=2.977, GLASS:  1504, z=2.995
# Boyett:   347, z=3.101, GLASS:   364, z=nan, sep=0.460 arcsec
# Boyett:   338, z=3.057, GLASS:  3524, z=nan, sep=0.178 arcsec
# Boyett:   878, z=3.038, GLASS:   892, z=nan, sep=0.212 arcsec
# Boyett:  1874, z=3.046, GLASS:  1984, z=3.053
# Boyett:  2218, z=3.198, GLASS:  2402, z=nan, sep=0.048 arcsec
# Boyett:   683, z=3.235, GLASS:   724, z=nan, sep=0.107 arcsec
# Boyett:  2671, z=3.398, GLASS:  2982, z=3.384
# WARNING: UnitsWarning: '0.1nm' did not parse as fits unit: Numeric factor not supported by FITS If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: '0.1nm' did not parse as fits unit: Numeric factor not supported by FITS If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: '0.1nm' did not parse as fits unit: Numeric factor not supported by FITS If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: '0.1nm' did not parse as fits unit: Numeric factor not supported by FITS If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: '0.1nm' did not parse as fits unit: Numeric factor not supported by FITS If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: '0.1nm' did not parse as fits unit: Numeric factor not supported by FITS If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: '0.1nm' did not parse as fits unit: Numeric factor not supported by FITS If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: '0.1nm' did not parse as fits unit: Numeric factor not supported by FITS If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]

# %%
stage_4_cat[325:350]
# Out:
# <Table length=25>
#   ID          RA                 DEC         ... Z_REFIT          DZ_1PZ
# int64      float64             float64       ...   bool          float64
# ----- ------------------ ------------------- ... ------- -----------------------
#   341   3.60264402614227  -30.40987146725151 ...   False                     0.0
#   342 3.5846167616456124 -30.410005752428667 ...   False                     0.0
#   343 3.5923098235703956 -30.409872680571237 ...   False                     0.0
#   344  3.592120842829752 -30.409892958519936 ...   False                     0.0
#   345    3.5845813958251 -30.409794628262972 ...    True   0.0010216482424440776
#   346  3.591409306380343  -30.40992286290728 ...   False                     0.0
#   347 3.5997710893951793 -30.409764935315167 ...   False                     0.0
#   349   3.60910219106354  -30.40965662282532 ...   False                     0.0
#   350 3.5925021421102605  -30.40984030801854 ...   False                     0.0
#   ...                ...                 ... ...     ...                     ...
#   357  3.600797201388178  -30.40951340009394 ...   False                     0.0
#   358  3.591417332955212  -30.40979070597433 ...   False                     0.0
#   359   3.58422119166082  -30.40973333525724 ...   False                     0.0
#   360  3.587943921727068  -30.40972438683857 ...   False                     0.0
#   361  3.606580095059353 -30.409696641382645 ...    True -0.00038452093802602243
#   362  3.593538208369151 -30.409684971894617 ...   False                     0.0
#   363 3.5876563733057307 -30.409725748040433 ...   False                     0.0
#   364 3.5939778504175353 -30.409616133883876 ...   False                     0.0
#   365 3.5831569634281903 -30.409703404219584 ...   False                     0.0
#   366  3.587432274059869  -30.40972170136241 ...   False                     0.0

# %%
stage_4_dir = grizli_home_dir / "Extractions_v4"
(stage_4_dir / "catalogues").mkdir(exist_ok=True, parents=True)


print(np.unique(np.array(stage_4_cat["Z_FLAG"]), return_counts=True))
# print (column_names)
print(np.nansum(stage_4_cat["Z_ON_EDGE"]))
print(np.nansum(stage_4_cat["Z_REFIT"]))
print(
    np.nansum(
        stage_4_cat["Z_REFIT"]
        & (~stage_4_cat["Z_OUTSIDE"])
        & (np.abs(stage_4_cat["DZ_1PZ"]) > 0.001)
    )
)
print(np.nansum(stage_4_cat["Z_REFIT"] & stage_4_cat["Z_OUTSIDE"]))
# with np.printoptions(threshold=np.inf):
#     for s in stage_4_cat[stage_4_cat["Z_REFIT"] & (~stage_4_cat["Z_OUTSIDE"]) & (np.abs(stage_4_cat["DZ_1PZ"])>0.001)]["ID","Z_NIRISS","DZ_1PZ"]:
#         print (list(s))

mag_cat = detect_cat["NUMBER","MAG_AUTO"]

stage_4_cat = join(stage_4_cat, mag_cat, keys_left=["ID"], keys_right=["NUMBER"])


stage_4_cat.write( stage_4_dir / "catalogues" / "stage_4_input.fits")
# Out:
# (array([0, 1, 2, 3, 4]), array([ 511,  907, 1625,  133,  478]))
# 93
# 133
# 69
# 3
# WARNING: VerifyWarning: Keyword name 'FILTER_TYPE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'THRESHOLD' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'BACK_PIXEL_SCALE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'ERR_SCALE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
